# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
data = pd.read_csv('cardio_train1.csv')

# %%
data['age'] = data['age']  //  365

# %%
data.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2     168    62.0    110     80            1     1      0
# 1   1   55       1     156    85.0    140     90            3     1      0
# 2   2   51       1     165    64.0    130     70            3     1      0
# 3   3   48       2     169    82.0    150    100            1     1      0
# 4   4   47       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
X = data.iloc[:, 1:-1]
y = data.iloc[:, -1]

# %%
from sklearn.preprocessing import StandardScaler
mms = StandardScaler()
X = mms.fit_transform(X)

# %%
np.shape(X)
# Out:
# (70000, 11)

# %%
y = pd.get_dummies(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33123)

# %%
_, _, _, y_test_r = train_test_split(X, data.iloc[:, -1], random_state=33123)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(11, activation='relu', input_shape=(11,)),
    tf.keras.layers.Dense(30, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(40, activation='relu'),
    tf.keras.layers.Dense(25, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=tf.keras.losses.CategoricalCrossentropy(), metrics=[tf.keras.metrics.CategoricalAccuracy()])
# Out:
# c:\Users\taha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │           360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 60)             │         1,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 80)             │         4,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 40)             │         3,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 25)             │         1,025 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 2)              │            52 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,549 (45.11 KB)
#  Trainable params: 11,549 (45.11 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=50)
# Out:
# Epoch 1/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - categorical_accuracy: 0.6752 - loss: 0.6077 - val_categorical_accuracy: 0.7169 - val_loss: 0.5725
# Epoch 2/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7192 - loss: 0.5614 - val_categorical_accuracy: 0.7197 - val_loss: 0.5599
# Epoch 3/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7230 - loss: 0.5542 - val_categorical_accuracy: 0.7257 - val_loss: 0.5527
# Epoch 4/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - categorical_accuracy: 0.7265 - loss: 0.5506 - val_categorical_accuracy: 0.7276 - val_loss: 0.5536
# Epoch 5/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7315 - loss: 0.5471 - val_categorical_accuracy: 0.7281 - val_loss: 0.5502
# Epoch 6/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7330 - loss: 0.5457 - val_categorical_accuracy: 0.7304 - val_loss: 0.5481
# Epoch 7/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7333 - loss: 0.5449 - val_categorical_accuracy: 0.7278 - val_loss: 0.5519
# Epoch 8/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7341 - loss: 0.5439 - val_categorical_accuracy: 0.7320 - val_loss: 0.5491
# Epoch 9/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7345 - loss: 0.5431 - val_categorical_accuracy: 0.7293 - val_loss: 0.5502
# Epoch 10/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7348 - loss: 0.5423 - val_categorical_accuracy: 0.7263 - val_loss: 0.5506
# Epoch 11/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7357 - loss: 0.5420 - val_categorical_accuracy: 0.7306 - val_loss: 0.5475
# Epoch 12/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7357 - loss: 0.5416 - val_categorical_accuracy: 0.7327 - val_loss: 0.5461
# Epoch 13/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7360 - loss: 0.5412 - val_categorical_accuracy: 0.7309 - val_loss: 0.5475
# Epoch 14/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7361 - loss: 0.5407 - val_categorical_accuracy: 0.7310 - val_loss: 0.5454
# Epoch 15/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7368 - loss: 0.5404 - val_categorical_accuracy: 0.7294 - val_loss: 0.5460
# Epoch 16/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7369 - loss: 0.5406 - val_categorical_accuracy: 0.7325 - val_loss: 0.5484
# Epoch 17/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7368 - loss: 0.5395 - val_categorical_accuracy: 0.7317 - val_loss: 0.5455
# Epoch 18/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7372 - loss: 0.5391 - val_categorical_accuracy: 0.7322 - val_loss: 0.5469
# Epoch 19/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - categorical_accuracy: 0.7372 - loss: 0.5387 - val_categorical_accuracy: 0.7319 - val_loss: 0.5466
# Epoch 20/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7374 - loss: 0.5385 - val_categorical_accuracy: 0.7322 - val_loss: 0.5460
# Epoch 21/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7376 - loss: 0.5389 - val_categorical_accuracy: 0.7303 - val_loss: 0.5518
# Epoch 22/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7385 - loss: 0.5383 - val_categorical_accuracy: 0.7334 - val_loss: 0.5450
# Epoch 23/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7375 - loss: 0.5378 - val_categorical_accuracy: 0.7323 - val_loss: 0.5472
# Epoch 24/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7392 - loss: 0.5374 - val_categorical_accuracy: 0.7327 - val_loss: 0.5454
# Epoch 25/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7377 - loss: 0.5373 - val_categorical_accuracy: 0.7326 - val_loss: 0.5478
# Epoch 26/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - categorical_accuracy: 0.7380 - loss: 0.5377 - val_categorical_accuracy: 0.7289 - val_loss: 0.5488
# Epoch 27/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7381 - loss: 0.5370 - val_categorical_accuracy: 0.7313 - val_loss: 0.5469
# Epoch 28/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7390 - loss: 0.5367 - val_categorical_accuracy: 0.7311 - val_loss: 0.5470
# Epoch 29/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7380 - loss: 0.5366 - val_categorical_accuracy: 0.7325 - val_loss: 0.5474
# Epoch 30/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7393 - loss: 0.5363 - val_categorical_accuracy: 0.7314 - val_loss: 0.5504
# Epoch 31/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7396 - loss: 0.5354 - val_categorical_accuracy: 0.7334 - val_loss: 0.5464
# Epoch 32/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7400 - loss: 0.5353 - val_categorical_accuracy: 0.7329 - val_loss: 0.5465
# Epoch 33/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7398 - loss: 0.5350 - val_categorical_accuracy: 0.7301 - val_loss: 0.5503
# Epoch 34/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7404 - loss: 0.5347 - val_categorical_accuracy: 0.7319 - val_loss: 0.5476
# Epoch 35/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7416 - loss: 0.5339 - val_categorical_accuracy: 0.7332 - val_loss: 0.5491
# Epoch 36/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7404 - loss: 0.5342 - val_categorical_accuracy: 0.7323 - val_loss: 0.5479
# Epoch 37/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7406 - loss: 0.5340 - val_categorical_accuracy: 0.7320 - val_loss: 0.5487
# Epoch 38/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7400 - loss: 0.5337 - val_categorical_accuracy: 0.7285 - val_loss: 0.5507
# Epoch 39/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7404 - loss: 0.5329 - val_categorical_accuracy: 0.7312 - val_loss: 0.5485
# Epoch 40/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7416 - loss: 0.5331 - val_categorical_accuracy: 0.7327 - val_loss: 0.5480
# Epoch 41/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7408 - loss: 0.5327 - val_categorical_accuracy: 0.7331 - val_loss: 0.5496
# Epoch 42/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7415 - loss: 0.5323 - val_categorical_accuracy: 0.7304 - val_loss: 0.5486
# Epoch 43/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7415 - loss: 0.5318 - val_categorical_accuracy: 0.7306 - val_loss: 0.5505
# Epoch 44/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7418 - loss: 0.5315 - val_categorical_accuracy: 0.7311 - val_loss: 0.5515
# Epoch 45/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7421 - loss: 0.5313 - val_categorical_accuracy: 0.7320 - val_loss: 0.5517
# Epoch 46/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7412 - loss: 0.5312 - val_categorical_accuracy: 0.7317 - val_loss: 0.5497
# Epoch 47/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - categorical_accuracy: 0.7423 - loss: 0.5311 - val_categorical_accuracy: 0.7319 - val_loss: 0.5492
# Epoch 48/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - categorical_accuracy: 0.7421 - loss: 0.5306 - val_categorical_accuracy: 0.7299 - val_loss: 0.5531
# Epoch 49/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7420 - loss: 0.5300 - val_categorical_accuracy: 0.7274 - val_loss: 0.5547
# Epoch 50/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - categorical_accuracy: 0.7428 - loss: 0.5303 - val_categorical_accuracy: 0.7311 - val_loss: 0.5503

# %%
model.predict(X_test)[3][1] > 0.3
# Out:
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# True

# %%
y_pred = model.predict(X_test)
# Out:
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_pred_n1 = y_pred[:, 1]

# %%
y_pred_n1[y_pred_n1 > 0.40] = 1
y_pred_n1[y_pred_n1 <= 0.40] = 0

# %%
y_pred_n1
# Out:
# array([1., 1., 1., ..., 1., 1., 0.], dtype=float32)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true=y_test_r, y_pred=y_pred_n1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.64      0.69      8652
#            1       0.69      0.79      0.74      8848
#
#     accuracy                           0.71     17500
#    macro avg       0.72      0.71      0.71     17500
# weighted avg       0.72      0.71      0.71     17500
